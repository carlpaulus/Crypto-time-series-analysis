# %%
from prophet import Prophet as proph

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
PORTFOLIO = 'BTC-USD'
start = '2016-01-01'
end = '2021-09-1'

# %%
dataset = pd.DataFrame(yf.download(PORTFOLIO, start=start, end=end).ffill().dropna())
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
dataset.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-12-31  425.875000  432.920990  418.734985  430.566986  430.566986
# 2016-01-01  430.721008  436.246002  427.515015  434.334015  434.334015
# 2016-01-02  434.622009  436.062012  431.869995  433.437988  433.437988
# 2016-01-03  433.578003  433.743011  424.705994  430.010986  430.010986
# 2016-01-04  430.061005  434.516998  429.084015  433.091003  433.091003
#
#               Volume
# Date
# 2015-12-31  45996600
# 2016-01-01  36278900
# 2016-01-02  30096600
# 2016-01-03  39633800
# 2016-01-04  38477500

# %%
dataset.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-08-27  46894.554688  49112.785156  46394.281250  49058.667969
# 2021-08-28  49072.585938  49283.503906  48499.238281  48902.402344
# 2021-08-29  48911.250000  49644.113281  47925.855469  48829.832031
# 2021-08-30  48834.851562  48925.605469  46950.273438  47054.984375
# 2021-08-31  47024.339844  48189.550781  46750.093750  47166.687500
#
#                Adj Close       Volume
# Date
# 2021-08-27  49058.667969  34511076995
# 2021-08-28  48902.402344  28568103401
# 2021-08-29  48829.832031  25889650240
# 2021-08-30  47054.984375  31847007016
# 2021-08-31  47166.687500  34730363427

# %%
dataset['ds'] = dataset.index

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
final_dataset = dataset[["ds","Close"]]
final_dataset.reset_index(drop=True, inplace=True)

# %%
final_dataset.head()
# Out:
#           ds       Close
# 0 2015-12-31  430.566986
# 1 2016-01-01  434.334015
# 2 2016-01-02  433.437988
# 3 2016-01-03  430.010986
# 4 2016-01-04  433.091003

# %%
# Renaming the columns for use in FB prophet
final_dataset.rename(columns={'Close': 'y'}, inplace=True)
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
final_dataset.head()
# Out:
#           ds           y
# 0 2015-12-31  430.566986
# 1 2016-01-01  434.334015
# 2 2016-01-02  433.437988
# 3 2016-01-03  430.010986
# 4 2016-01-04  433.091003

# %%
# Plotting the price 
pd.plotting.register_matplotlib_converters()

ax = final_dataset.set_index('ds').plot(figsize=(16,8))
ax.set_ylabel('Bitcoin Closing Price')
ax.set_xlabel('Date')

plt.show()

# %%
final_dataset.describe()
# Out:
#                   y
# count   2067.000000
# mean   10621.572117
# std    13519.191569
# min      364.330994
# 25%     2244.475098
# 50%     7022.759766
# 75%    10359.297852
# max    63503.457031

# %%
final_dataset
# Out:
#              ds             y
# 0    2015-12-31    430.566986
# 1    2016-01-01    434.334015
# 2    2016-01-02    433.437988
# 3    2016-01-03    430.010986
# 4    2016-01-04    433.091003
# ...         ...           ...
# 2062 2021-08-27  49058.667969
# 2063 2021-08-28  48902.402344
# 2064 2021-08-29  48829.832031
# 2065 2021-08-30  47054.984375
# 2066 2021-08-31  47166.687500
#
# [2067 rows x 2 columns]

# %%
final_dataset
# Out:
#              ds             y
# 0    2015-12-31    430.566986
# 1    2016-01-01    434.334015
# 2    2016-01-02    433.437988
# 3    2016-01-03    430.010986
# 4    2016-01-04    433.091003
# ...         ...           ...
# 2062 2021-08-27  49058.667969
# 2063 2021-08-28  48902.402344
# 2064 2021-08-29  48829.832031
# 2065 2021-08-30  47054.984375
# 2066 2021-08-31  47166.687500
#
# [2067 rows x 2 columns]

# %%
# Fitting and training
mod = proph(interval_width=0.95, growth = 'linear', daily_seasonality=False, 
            seasonality_mode = 'multiplicative').add_seasonality(name='daily',period=1,fourier_order=15)
mod.fit(final_dataset)

# %%
future = mod.make_future_dataframe(periods=61, freq='D')

future.tail()
future['floor']=0

# %%
forecast = mod.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']]
# Out:
#              ds          yhat    yhat_lower    yhat_upper
# 0    2015-12-31    313.255957  -2495.521953   3422.318047
# 1    2016-01-01    321.020332  -2746.441368   3032.671714
# 2    2016-01-02    325.908450  -2581.627203   3224.668110
# 3    2016-01-03    329.852671  -2495.253222   3031.203755
# 4    2016-01-04    333.852254  -2556.577838   3419.026834
# ...         ...           ...           ...           ...
# 2123 2021-10-27  37549.245368  33579.828716  41593.750752
# 2124 2021-10-28  37651.621217  33392.253061  41428.687807
# 2125 2021-10-29  38346.585362  33992.778483  42549.579320
# 2126 2021-10-30  38515.333973  34331.238385  42467.506890
# 2127 2021-10-31  38555.571693  34591.932276  42760.700481
#
# [2128 rows x 4 columns]

# %% [markdown]
# Blue line = Forecasted values
# Black dots = Observed (actual) values
# Blue-shaded region = Uncertainty intervals#

# %%
mod.plot(forecast, uncertainty=True)
plt.title('Facebook Prophet Forecast and Fitting')
plt.show()

# %%
mod.plot_components(forecast)
plt.show()

# %%
PORTFOLIO = 'BTC-USD'
actual_start = '2021-09-02'
actual_end = '2021-11-1'

# %%
actual_data = pd.DataFrame(yf.download(PORTFOLIO, start=actual_start, end=actual_end).ffill().dropna())
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
actual_data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-09-01  47099.773438  49111.089844  46562.437500  48847.027344
# 2021-09-02  48807.847656  50343.421875  48652.320312  49327.722656
# 2021-09-03  49288.250000  50982.273438  48386.085938  50025.375000
# 2021-09-04  50009.324219  50545.582031  49548.781250  49944.625000
# 2021-09-05  49937.859375  51868.679688  49538.597656  51753.410156
#
#                Adj Close       Volume
# Date
# 2021-09-01  48847.027344  39139399125
# 2021-09-02  49327.722656  39508070319
# 2021-09-03  50025.375000  43206179619
# 2021-09-04  49944.625000  37471327794
# 2021-09-05  51753.410156  30322676319

# %%
actual_data.tail()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-10-27  60352.000000  61435.183594  58208.187500  58482.386719
# 2021-10-28  58470.730469  62128.632812  58206.917969  60622.136719
# 2021-10-29  60624.871094  62927.609375  60329.964844  62227.964844
# 2021-10-30  62239.363281  62330.144531  60918.386719  61888.832031
# 2021-10-31  61850.488281  62406.171875  60074.328125  61318.957031
#
#                Adj Close       Volume
# Date
# 2021-10-27  58482.386719  43657076893
# 2021-10-28  60622.136719  45257083247
# 2021-10-29  62227.964844  36856881767
# 2021-10-30  61888.832031  32157938616
# 2021-10-31  61318.957031  32241199927

# %%
actual_data['ds'] = actual_data.index

# %%
actual_data = actual_data[["ds","Close"]]
actual_data.reset_index(drop=True, inplace=True)

# %%
actual_data.head()
# Out:
#           ds         Close
# 0 2021-09-01  48847.027344
# 1 2021-09-02  49327.722656
# 2 2021-09-03  50025.375000
# 3 2021-09-04  49944.625000
# 4 2021-09-05  51753.410156

# %%
check2 = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]

# %%
compare = pd.merge(actual_data,check2)

# %%
compare.head()
# Out:
#           ds         Close          yhat    yhat_lower    yhat_upper
# 0 2021-09-01  48847.027344  42725.920093  39813.866868  45554.297324
# 1 2021-09-02  49327.722656  42008.092024  39142.676429  44946.139735
# 2 2021-09-03  50025.375000  41838.218283  38948.800456  44847.934604
# 3 2021-09-04  49944.625000  41209.946786  38112.801170  44071.453339
# 4 2021-09-05  51753.410156  40487.221858  37886.138326  43184.593110

# %%
compare = compare.rename(columns={'Close': 'Actual_Close','yhat': 'Projected_Close','yhat_lower' : 'Projected_Close_lower','yhat_upper' : 'Projected_Close_upper' })

# %%
compare.head()
# Out:
#           ds  Actual_Close  Projected_Close  Projected_Close_lower  \
# 0 2021-09-01  48847.027344     42725.920093           39813.866868
# 1 2021-09-02  49327.722656     42008.092024           39142.676429
# 2 2021-09-03  50025.375000     41838.218283           38948.800456
# 3 2021-09-04  49944.625000     41209.946786           38112.801170
# 4 2021-09-05  51753.410156     40487.221858           37886.138326
#
#    Projected_Close_upper
# 0           45554.297324
# 1           44946.139735
# 2           44847.934604
# 3           44071.453339
# 4           43184.593110

# %%
compare["Session_Delta"] = compare.Actual_Close - compare.Projected_Close
compare
# Out:
#            ds  Actual_Close  Projected_Close  Projected_Close_lower  \
# 0  2021-09-01  48847.027344     42725.920093           39813.866868
# 1  2021-09-02  49327.722656     42008.092024           39142.676429
# 2  2021-09-03  50025.375000     41838.218283           38948.800456
# 3  2021-09-04  49944.625000     41209.946786           38112.801170
# 4  2021-09-05  51753.410156     40487.221858           37886.138326
# ..        ...           ...              ...                    ...
# 56 2021-10-27  58482.386719     37549.245368           33579.828716
# 57 2021-10-28  60622.136719     37651.621217           33392.253061
# 58 2021-10-29  62227.964844     38346.585362           33992.778483
# 59 2021-10-30  61888.832031     38515.333973           34331.238385
# 60 2021-10-31  61318.957031     38555.571693           34591.932276
#
#     Projected_Close_upper  Session_Delta
# 0            45554.297324    6121.107250
# 1            44946.139735    7319.630632
# 2            44847.934604    8187.156717
# 3            44071.453339    8734.678214
# 4            43184.593110   11266.188299
# ..                    ...            ...
# 56           41593.750752   20933.141351
# 57           41428.687807   22970.515501
# 58           42549.579320   23881.379482
# 59           42467.506890   23373.498058
# 60           42760.700481   22763.385339
#
# [61 rows x 6 columns]

# %%
compare.Session_Delta.describe()
# Out:
# count       61.000000
# mean     16581.251424
# std       7463.790014
# min       6121.107250
# 25%       9390.727735
# 50%      15292.423005
# 75%      23373.498058
# max      30606.421356
# Name: Session_Delta, dtype: float64

# %%
compare['ds'] = compare['ds'].dt.date

# %%
fig, ax = plt.subplots(figsize=(9, 6))
compare.plot("ds", "Session_Delta", ax=ax)
fig.autofmt_xdate(bottom=0.2, rotation=30, ha='right');

# %%
fig, ax = plt.subplots(figsize=(9, 8))
compare.plot('ds',['Actual_Close','Projected_Close'],ax=ax)
fig.autofmt_xdate(bottom=0.5, rotation=40, ha='right');
